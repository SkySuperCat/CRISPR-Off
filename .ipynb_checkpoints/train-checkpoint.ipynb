# %%
import tensorflow as tf
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_auc_score, average_precision_score
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import model_get
import pickle as pkl
import time
import GPUtil

# %% [markdown]
# # Utils

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)

def loadGlove(inputpath, outputpath=""):
    data_list = []
    wordEmb = {}
    with open(inputpath) as f:
        for line in f:
            ll = line.strip().split(',')
            ll[0] = str(int(float(ll[0])))
            data_list.append(ll)

            ll_new = [float(i) for i in ll]
            emb = np.array(ll_new[1:], dtype="float32")
            wordEmb[str(int(ll_new[0]))] = emb

    if outputpath != "":
        with open(outputpath) as f:
            for data in data_list:
                f.writelines(' '.join(data))
    return wordEmb

# %% [markdown]
# # Setting

# %%
import random
import os
seed = 123
random.seed(seed)
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)


def f1_metric(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
    predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return f1_val


early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_f1_metric', min_delta=0.0001,
    patience=10, verbose=0, mode='max')
callbacks = [early_stopping]

dataset = 'hek293t'

num_classes = 2
epochs = 30
batch_size = 128
flpath = 'data/'


retrain = False

# %% [markdown]
# # Model Training

# %% [markdown]
# CrisprIP

# %%
print('crispr_ip_model')
encoder_shape = (23, 6)
seg_len, coding_dim = encoder_shape

open_name = 'encoded6x23' + dataset + '.pkl'


print('load data!')
print(open_name)

loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    np.array(loaddata.images),
    loaddata.target,  # loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,  # loaddata.target,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)



xtrain, xtest1, ytrain, ytest1, xval, yval, inputshape = model_get.transformIO(
    x_train, x_test, y_train, y_test, x_val, y_val, seg_len, coding_dim, num_classes)

pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))

pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()

resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)
resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)


print('Training!!')
# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")

crispr_ip_model = model_get.crispr_ip(test_ds, resampled_steps_per_epoch, resampled_ds, xtrain, ytrain,
                                       xtest1,
                                       ytest1,
                                       inputshape, num_classes, batch_size, epochs, callbacks,
                                       dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")


yscore = crispr_ip_model.predict(xtest1)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest1, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# crispr_ip_model
# load data!
# encoded6x23CIRCLE.pkl
# 369649
# xtrain shape: (374367, 1, 23, 6)
# 374367 train samples
# 116990 test samples
# 93592 val samples
# 4718
# 369649
# 5776.0
# Training!!
# Initial GPU Memory Usage: 7234.0 MB
# Epoch 1/30
# 5776/5776 [==============================] - 57s 10ms/step - loss: 0.6934 - accuracy: 0.4998 - f1_metric: 0.4998 - val_loss: 0.6920 - val_accuracy: 0.9785 - val_f1_metric: 0.9778
# Epoch 2/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.6933 - accuracy: 0.4999 - f1_metric: 0.4999 - val_loss: 0.6870 - val_accuracy: 0.2285 - val_f1_metric: 0.2290
# Epoch 3/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.6933 - accuracy: 0.4995 - f1_metric: 0.4995 - val_loss: 1.1220 - val_accuracy: 0.0126 - val_f1_metric: 0.0126
# Epoch 4/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.6933 - accuracy: 0.4993 - f1_metric: 0.4993 - val_loss: 0.4398 - val_accuracy: 0.9860 - val_f1_metric: 0.9860
# Epoch 5/30
# 5776/5776 [==============================] - 58s 10ms/step - loss: 0.6932 - accuracy: 0.4992 - f1_metric: 0.4992 - val_loss: 0.6655 - val_accuracy: 0.9860 - val_f1_metric: 0.9861
# Epoch 6/30
# 5776/5776 [==============================] - 61s 11ms/step - loss: 0.6932 - accuracy: 0.5006 - f1_metric: 0.5006 - val_loss: 0.6441 - val_accuracy: 0.7610 - val_f1_metric: 0.7605
# Epoch 7/30
# 5776/5776 [==============================] - 62s 11ms/step - loss: 0.6932 - accuracy: 0.4995 - f1_metric: 0.4995 - val_loss: 1.5160 - val_accuracy: 0.0148 - val_f1_metric: 0.0151
# Epoch 8/30
# 5776/5776 [==============================] - 59s 10ms/step - loss: 0.6933 - accuracy: 0.4996 - f1_metric: 0.4996 - val_loss: 1.3233 - val_accuracy: 0.1604 - val_f1_metric: 0.1605
# Epoch 9/30
# 5776/5776 [==============================] - 58s 10ms/step - loss: 0.6933 - accuracy: 0.5002 - f1_metric: 0.5002 - val_loss: 7.2229 - val_accuracy: 0.0184 - val_f1_metric: 0.0193
# Epoch 10/30
# 5776/5776 [==============================] - 59s 10ms/step - loss: 0.6932 - accuracy: 0.4991 - f1_metric: 0.4991 - val_loss: 13.6770 - val_accuracy: 0.0126 - val_f1_metric: 0.0126
# Epoch 11/30
# 5776/5776 [==============================] - 61s 11ms/step - loss: 0.6932 - accuracy: 0.5008 - f1_metric: 0.5008 - val_loss: 3.7098 - val_accuracy: 0.0165 - val_f1_metric: 0.0165
# Epoch 12/30
# 5776/5776 [==============================] - 59s 10ms/step - loss: 0.6932 - accuracy: 0.4999 - f1_metric: 0.4999 - val_loss: 2.3692 - val_accuracy: 0.0274 - val_f1_metric: 0.0276
# Epoch 13/30
# 5776/5776 [==============================] - 59s 10ms/step - loss: 0.6932 - accuracy: 0.5001 - f1_metric: 0.5001 - val_loss: 2.9309 - val_accuracy: 0.0161 - val_f1_metric: 0.0161
# Epoch 14/30
# 5776/5776 [==============================] - 57s 10ms/step - loss: 0.6932 - accuracy: 0.5000 - f1_metric: 0.5000 - val_loss: 3.2877 - val_accuracy: 0.1414 - val_f1_metric: 0.1412
# Training Time: 821.80 seconds
# Final GPU Memory Usage: 7234.0 MB
# Accuracy                0.0307
# F1 score                0.0249
# Precision               0.0126
# Recall                   0.981
# ROC AUC                 0.5077
# PR AUC                  0.0129

# %% [markdown]
# cnn_std

# %%
print('cnn_std')
encoder_shape = (23, 4)
seg_len, coding_dim = encoder_shape
open_name = 'encoded4x23' + dataset + '.pkl'

print('load data!')
print(open_name)

loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    np.array(loaddata.images),
    loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)

xtrain, xtest2, ytrain, ytest2, xval, yval, input_shape = model_get.cnn_std_transformIO(x_train, x_test,
                                                                                         y_train,
                                                                                         y_test, x_val, y_val,
                                                                                         seg_len, coding_dim,
                                                                                         num_classes)
pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))

pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()

resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)
resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)

print('Training!!')
# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")
cnn_std_model = model_get.cnn_std(test_ds, resampled_steps_per_epoch, resampled_ds, xtrain, ytrain,
                                   xtest2,
                                   ytest2, num_classes, batch_size, epochs, callbacks,
                                   dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")

yscore = cnn_std_model.predict(xtest2)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest2, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# cnn_std
# load data!
# encoded4x23hek293t.pkl
# 36306
# xtrain shape: (36636, 1, 23, 4)
# 36636 train samples
# 11449 test samples
# 9160 xval samples
# 330
# 36306
# 568.0
# Training!!
# Initial GPU Memory Usage: 6936.0 MB
# Epoch 1/30

# %% [markdown]
# crisprDNT

# %%
print('crisprDNT')
open_name = 'encodedmismatchtype14x23' + dataset + '.pkl'
encoder_shape = (23, 14)
seg_len, coding_dim = encoder_shape

print('load data!')
print(open_name)

loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    loaddata.images,
    loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)

xtrain, xtest3, ytrain, ytest3, xval, yval, inputshape = model_get.transformIO(
    x_train, x_test, y_train, y_test, x_val, y_val, seg_len, coding_dim, num_classes)

pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))
pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()

resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)
resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)

print('Training!!')
# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")

crisprDNT = model_get.crisprDNT(test_ds, resampled_steps_per_epoch, resampled_ds, xtrain, ytrain,
                                     xtest3,
                                     ytest3,
                                     inputshape, num_classes, batch_size, epochs, callbacks,
                                     dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")


yscore = crisprDNT.predict(xtest3)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest3, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# crisprDNT
# load data!
# encodedmismatchtype14x23CIRCLE.pkl
# 369649
# xtrain shape: (374367, 1, 23, 14)
# 374367 train samples
# 116990 test samples
# 93592 val samples
# 4718
# 369649
# 5776.0
# Training!!
# Initial GPU Memory Usage: 7234.0 MB
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/30
# 5776/5776 [==============================] - 450s 78ms/step - loss: 0.1535 - accuracy: 0.9393 - f1_metric: 0.9393 - val_loss: 0.0839 - val_accuracy: 0.9714 - val_f1_metric: 0.9713
# Epoch 2/30
# 5776/5776 [==============================] - 437s 76ms/step - loss: 0.0475 - accuracy: 0.9855 - f1_metric: 0.9855 - val_loss: 0.1852 - val_accuracy: 0.9852 - val_f1_metric: 0.9852
# Epoch 3/30
# 5776/5776 [==============================] - 413s 72ms/step - loss: 0.0305 - accuracy: 0.9909 - f1_metric: 0.9909 - val_loss: 0.0834 - val_accuracy: 0.9869 - val_f1_metric: 0.9869
# Epoch 4/30
# 5776/5776 [==============================] - 432s 75ms/step - loss: 0.0234 - accuracy: 0.9932 - f1_metric: 0.9932 - val_loss: 0.0750 - val_accuracy: 0.9854 - val_f1_metric: 0.9853
# Epoch 5/30
# 5776/5776 [==============================] - 442s 77ms/step - loss: 0.0186 - accuracy: 0.9947 - f1_metric: 0.9947 - val_loss: 0.0787 - val_accuracy: 0.9848 - val_f1_metric: 0.9847
# Epoch 6/30
# 5776/5776 [==============================] - 442s 76ms/step - loss: 0.0160 - accuracy: 0.9954 - f1_metric: 0.9954 - val_loss: 0.0945 - val_accuracy: 0.9871 - val_f1_metric: 0.9870
# Epoch 7/30
# 5776/5776 [==============================] - 443s 77ms/step - loss: 0.0141 - accuracy: 0.9959 - f1_metric: 0.9959 - val_loss: 0.0742 - val_accuracy: 0.9861 - val_f1_metric: 0.9861
# Epoch 8/30
# 5776/5776 [==============================] - 462s 80ms/step - loss: 0.0122 - accuracy: 0.9965 - f1_metric: 0.9965 - val_loss: 0.0806 - val_accuracy: 0.9874 - val_f1_metric: 0.9873
# Epoch 9/30
# 5776/5776 [==============================] - 468s 81ms/step - loss: 0.0111 - accuracy: 0.9969 - f1_metric: 0.9969 - val_loss: 0.0774 - val_accuracy: 0.9884 - val_f1_metric: 0.9884
# Epoch 10/30
# 5776/5776 [==============================] - 473s 82ms/step - loss: 0.0099 - accuracy: 0.9971 - f1_metric: 0.9971 - val_loss: 0.0816 - val_accuracy: 0.9876 - val_f1_metric: 0.9876
# Epoch 11/30
# 5776/5776 [==============================] - 475s 82ms/step - loss: 0.0095 - accuracy: 0.9973 - f1_metric: 0.9973 - val_loss: 0.0835 - val_accuracy: 0.9899 - val_f1_metric: 0.9899
# Epoch 12/30
# 5776/5776 [==============================] - 475s 82ms/step - loss: 0.0089 - accuracy: 0.9974 - f1_metric: 0.9974 - val_loss: 0.0806 - val_accuracy: 0.9891 - val_f1_metric: 0.9890
# Epoch 13/30
# 5776/5776 [==============================] - 473s 82ms/step - loss: 0.0088 - accuracy: 0.9976 - f1_metric: 0.9976 - val_loss: 0.1121 - val_accuracy: 0.9888 - val_f1_metric: 0.9889
# Epoch 14/30
# 5776/5776 [==============================] - 471s 81ms/step - loss: 0.0081 - accuracy: 0.9978 - f1_metric: 0.9978 - val_loss: 0.0911 - val_accuracy: 0.9891 - val_f1_metric: 0.9891
# Epoch 15/30
# 5776/5776 [==============================] - 461s 80ms/step - loss: 0.0075 - accuracy: 0.9979 - f1_metric: 0.9979 - val_loss: 0.0922 - val_accuracy: 0.9886 - val_f1_metric: 0.9886
# Epoch 16/30
# 5776/5776 [==============================] - 405s 70ms/step - loss: 0.0073 - accuracy: 0.9979 - f1_metric: 0.9979 - val_loss: 0.0926 - val_accuracy: 0.9886 - val_f1_metric: 0.9886
# Epoch 17/30
# 5776/5776 [==============================] - 403s 70ms/step - loss: 0.0069 - accuracy: 0.9981 - f1_metric: 0.9981 - val_loss: 0.1018 - val_accuracy: 0.9893 - val_f1_metric: 0.9893
# Epoch 18/30
# 5776/5776 [==============================] - 402s 70ms/step - loss: 0.0065 - accuracy: 0.9982 - f1_metric: 0.9982 - val_loss: 0.0969 - val_accuracy: 0.9889 - val_f1_metric: 0.9888
# Epoch 19/30
# 5776/5776 [==============================] - 403s 70ms/step - loss: 0.0063 - accuracy: 0.9982 - f1_metric: 0.9982 - val_loss: 0.0971 - val_accuracy: 0.9906 - val_f1_metric: 0.9906
# Epoch 20/30
# 5776/5776 [==============================] - 401s 69ms/step - loss: 0.0064 - accuracy: 0.9982 - f1_metric: 0.9982 - val_loss: 0.0971 - val_accuracy: 0.9889 - val_f1_metric: 0.9889
# Epoch 21/30
# 5776/5776 [==============================] - 402s 70ms/step - loss: 0.0058 - accuracy: 0.9984 - f1_metric: 0.9984 - val_loss: 0.1013 - val_accuracy: 0.9905 - val_f1_metric: 0.9905
# Epoch 22/30
# 5776/5776 [==============================] - 402s 70ms/step - loss: 0.0064 - accuracy: 0.9983 - f1_metric: 0.9983 - val_loss: 0.2554 - val_accuracy: 0.9850 - val_f1_metric: 0.9850
# Epoch 23/30
# 5776/5776 [==============================] - 402s 70ms/step - loss: 0.0058 - accuracy: 0.9984 - f1_metric: 0.9984 - val_loss: 0.1202 - val_accuracy: 0.9871 - val_f1_metric: 0.9871
# Epoch 24/30
# 5776/5776 [==============================] - 430s 74ms/step - loss: 0.0058 - accuracy: 0.9984 - f1_metric: 0.9984 - val_loss: 0.0948 - val_accuracy: 0.9899 - val_f1_metric: 0.9899
# Epoch 25/30
# 5776/5776 [==============================] - 464s 80ms/step - loss: 0.0054 - accuracy: 0.9985 - f1_metric: 0.9985 - val_loss: 0.1030 - val_accuracy: 0.9911 - val_f1_metric: 0.9911
# Epoch 26/30
# 5776/5776 [==============================] - 459s 80ms/step - loss: 0.0059 - accuracy: 0.9984 - f1_metric: 0.9984 - val_loss: 0.0989 - val_accuracy: 0.9902 - val_f1_metric: 0.9902
# Epoch 27/30
# 5776/5776 [==============================] - 458s 79ms/step - loss: 0.0054 - accuracy: 0.9985 - f1_metric: 0.9985 - val_loss: 0.1064 - val_accuracy: 0.9900 - val_f1_metric: 0.9900
# Epoch 28/30
# 5776/5776 [==============================] - 471s 81ms/step - loss: 0.0053 - accuracy: 0.9986 - f1_metric: 0.9986 - val_loss: 0.1085 - val_accuracy: 0.9882 - val_f1_metric: 0.9882
# Epoch 29/30
# 5776/5776 [==============================] - 433s 75ms/step - loss: 0.0050 - accuracy: 0.9986 - f1_metric: 0.9986 - val_loss: 0.1126 - val_accuracy: 0.9903 - val_f1_metric: 0.9903
# Epoch 30/30
# 5776/5776 [==============================] - 458s 79ms/step - loss: 0.0054 - accuracy: 0.9985 - f1_metric: 0.9985 - val_loss: 0.1148 - val_accuracy: 0.9898 - val_f1_metric: 0.9898
# Training Time: 13214.41 seconds
# Final GPU Memory Usage: 7234.0 MB
# Accuracy                0.9904
# F1 score                0.6118
# Precision               0.6237
# Recall                  0.6004
# ROC AUC                 0.9646
# PR AUC                  0.6102

# %% [markdown]
# crisprNet

# %%
print('CRISPR_Net')
open_name = 'encoded7x23' + dataset + '.pkl'
encoder_shape = (23, 7)
seg_len, coding_dim = encoder_shape
print('load data!')
print(open_name)
loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    loaddata.images,
    loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)

xtrain, xtest4, ytrain, ytest4, xval, yval, inputshape = model_get.CRISPR_Net_transformIO(
    x_train, x_test, y_train, y_test, x_val, y_val, seg_len, coding_dim, num_classes)

pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))

pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()
resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)

resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)

print('Training!!')
# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")

CRISPR_Net_model = model_get.CRISPR_Net_model(test_ds, resampled_steps_per_epoch, resampled_ds,
                                               xtrain, ytrain,
                                               xtest4,
                                               ytest4,
                                               inputshape, num_classes, batch_size, epochs, callbacks,
                                               dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")


yscore = CRISPR_Net_model.predict(xtest4)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest4, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# CRISPR_Net
# load data!
# encoded7x23CIRCLE.pkl
# 369649
# xtrain shape: (374367, 1, 23, 7)
# 374367 train samples
# 116990 test samples
# 93592 val samples
# 4718
# 369649
# 5776.0
# Training!!
# Initial GPU Memory Usage: 7256.0 MB
# Epoch 1/30
# 5776/5776 [==============================] - 51s 9ms/step - loss: 0.1415 - accuracy: 0.9484 - f1_metric: 0.9484 - val_loss: 0.2783 - val_accuracy: 0.9654 - val_f1_metric: 0.9650
# Epoch 2/30
# 5776/5776 [==============================] - 52s 9ms/step - loss: 0.0878 - accuracy: 0.9699 - f1_metric: 0.9699 - val_loss: 0.1176 - val_accuracy: 0.9558 - val_f1_metric: 0.9557
# Epoch 3/30
# 5776/5776 [==============================] - 51s 9ms/step - loss: 0.0542 - accuracy: 0.9834 - f1_metric: 0.9834 - val_loss: 0.1381 - val_accuracy: 0.9572 - val_f1_metric: 0.9571
# Epoch 4/30
# 5776/5776 [==============================] - 51s 9ms/step - loss: 0.0433 - accuracy: 0.9874 - f1_metric: 0.9874 - val_loss: 0.0738 - val_accuracy: 0.9799 - val_f1_metric: 0.9798
# Epoch 5/30
# 5776/5776 [==============================] - 55s 10ms/step - loss: 0.0354 - accuracy: 0.9901 - f1_metric: 0.9901 - val_loss: 0.0808 - val_accuracy: 0.9815 - val_f1_metric: 0.9814
# Epoch 6/30
# 5776/5776 [==============================] - 58s 10ms/step - loss: 0.0304 - accuracy: 0.9918 - f1_metric: 0.9918 - val_loss: 0.0963 - val_accuracy: 0.9794 - val_f1_metric: 0.9794
# Epoch 7/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0276 - accuracy: 0.9926 - f1_metric: 0.9926 - val_loss: 0.0771 - val_accuracy: 0.9860 - val_f1_metric: 0.9860
# Epoch 8/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0249 - accuracy: 0.9934 - f1_metric: 0.9934 - val_loss: 0.0793 - val_accuracy: 0.9858 - val_f1_metric: 0.9858
# Epoch 9/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0211 - accuracy: 0.9945 - f1_metric: 0.9945 - val_loss: 0.0825 - val_accuracy: 0.9875 - val_f1_metric: 0.9874
# Epoch 10/30
# 5776/5776 [==============================] - 57s 10ms/step - loss: 0.0195 - accuracy: 0.9951 - f1_metric: 0.9951 - val_loss: 0.0835 - val_accuracy: 0.9891 - val_f1_metric: 0.9891
# Epoch 11/30
# 5776/5776 [==============================] - 58s 10ms/step - loss: 0.0181 - accuracy: 0.9954 - f1_metric: 0.9954 - val_loss: 0.0816 - val_accuracy: 0.9883 - val_f1_metric: 0.9881
# Epoch 12/30
# 5776/5776 [==============================] - 55s 10ms/step - loss: 0.0163 - accuracy: 0.9958 - f1_metric: 0.9958 - val_loss: 0.0875 - val_accuracy: 0.9881 - val_f1_metric: 0.9879
# Epoch 13/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0152 - accuracy: 0.9961 - f1_metric: 0.9961 - val_loss: 0.0886 - val_accuracy: 0.9896 - val_f1_metric: 0.9896
# Epoch 14/30
# 5776/5776 [==============================] - 57s 10ms/step - loss: 0.0136 - accuracy: 0.9966 - f1_metric: 0.9966 - val_loss: 0.0960 - val_accuracy: 0.9887 - val_f1_metric: 0.9886
# Epoch 15/30
# 5776/5776 [==============================] - 52s 9ms/step - loss: 0.0127 - accuracy: 0.9968 - f1_metric: 0.9968 - val_loss: 0.0969 - val_accuracy: 0.9884 - val_f1_metric: 0.9883
# Epoch 16/30
# 5776/5776 [==============================] - 52s 9ms/step - loss: 0.0121 - accuracy: 0.9969 - f1_metric: 0.9969 - val_loss: 0.0998 - val_accuracy: 0.9886 - val_f1_metric: 0.9887
# Epoch 17/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0113 - accuracy: 0.9971 - f1_metric: 0.9971 - val_loss: 0.0952 - val_accuracy: 0.9898 - val_f1_metric: 0.9898
# Epoch 18/30
# 5776/5776 [==============================] - 57s 10ms/step - loss: 0.0105 - accuracy: 0.9974 - f1_metric: 0.9974 - val_loss: 0.1002 - val_accuracy: 0.9893 - val_f1_metric: 0.9892
# Epoch 19/30
# 5776/5776 [==============================] - 55s 10ms/step - loss: 0.0099 - accuracy: 0.9975 - f1_metric: 0.9975 - val_loss: 0.0980 - val_accuracy: 0.9901 - val_f1_metric: 0.9901
# Epoch 20/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0091 - accuracy: 0.9977 - f1_metric: 0.9977 - val_loss: 0.0977 - val_accuracy: 0.9895 - val_f1_metric: 0.9895
# Epoch 21/30
# 5776/5776 [==============================] - 55s 10ms/step - loss: 0.0089 - accuracy: 0.9978 - f1_metric: 0.9978 - val_loss: 0.0980 - val_accuracy: 0.9907 - val_f1_metric: 0.9906
# Epoch 22/30
# 5776/5776 [==============================] - 55s 10ms/step - loss: 0.0082 - accuracy: 0.9980 - f1_metric: 0.9980 - val_loss: 0.1009 - val_accuracy: 0.9892 - val_f1_metric: 0.9891
# Epoch 23/30
# 5776/5776 [==============================] - 57s 10ms/step - loss: 0.0079 - accuracy: 0.9980 - f1_metric: 0.9980 - val_loss: 0.1034 - val_accuracy: 0.9903 - val_f1_metric: 0.9903
# Epoch 24/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0074 - accuracy: 0.9981 - f1_metric: 0.9981 - val_loss: 0.1038 - val_accuracy: 0.9903 - val_f1_metric: 0.9903
# Epoch 25/30
# 5776/5776 [==============================] - 57s 10ms/step - loss: 0.0073 - accuracy: 0.9982 - f1_metric: 0.9982 - val_loss: 0.0972 - val_accuracy: 0.9905 - val_f1_metric: 0.9905
# Epoch 26/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0063 - accuracy: 0.9984 - f1_metric: 0.9984 - val_loss: 0.1049 - val_accuracy: 0.9903 - val_f1_metric: 0.9903
# Epoch 27/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0063 - accuracy: 0.9984 - f1_metric: 0.9984 - val_loss: 0.1133 - val_accuracy: 0.9891 - val_f1_metric: 0.9891
# Epoch 28/30
# 5776/5776 [==============================] - 56s 10ms/step - loss: 0.0059 - accuracy: 0.9985 - f1_metric: 0.9985 - val_loss: 0.1126 - val_accuracy: 0.9892 - val_f1_metric: 0.9892
# Epoch 29/30
# 5776/5776 [==============================] - 50s 9ms/step - loss: 0.0062 - accuracy: 0.9984 - f1_metric: 0.9984 - val_loss: 0.1059 - val_accuracy: 0.9883 - val_f1_metric: 0.9883
# Epoch 30/30
# 5776/5776 [==============================] - 55s 9ms/step - loss: 0.0055 - accuracy: 0.9986 - f1_metric: 0.9986 - val_loss: 0.1133 - val_accuracy: 0.9884 - val_f1_metric: 0.9884
# Training Time: 1654.07 seconds
# Final GPU Memory Usage: 7256.0 MB
# Accuracy                0.9876
# F1 score                0.5966
# Precision               0.5047
# Recall                  0.7293
# ROC AUC                 0.9796
# PR AUC                  0.6555

# %% [markdown]
# cnnCRISPR

# %%
print('cnn_crispr model')
print("GloVe model loaded")
VOCAB_SIZE = 16  # 4**3
EMBED_SIZE = 100
glove_inputpath = "data/keras_GloVeVec_" + dataset + "_5_100_10000.csv"
# load GloVe model
model_glove = loadGlove(glove_inputpath)
embedding_weights = np.zeros((VOCAB_SIZE, EMBED_SIZE))
for i in range(VOCAB_SIZE):
    embedding_weights[i, :] = model_glove[str(i)]

open_name = 'encoded_CnnCrispr_' + dataset + '.pkl'


print('load data!')
print(open_name)

loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    np.array(loaddata.images),
    loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)

xtrain, xtest5, ytrain, ytest5, xval, yval = model_get.offt_transformIO(x_train, x_test, y_train, y_test,
                                                                         x_val, y_val, num_classes)

pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))

pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()

resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)
resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)

print('Training!!')

# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")

CnnCrispr_model = model_get.CnnCrispr(embedding_weights, test_ds, resampled_steps_per_epoch, resampled_ds,
                                       xtrain, ytrain,
                                       xtest5,
                                       ytest5, num_classes, batch_size, epochs, callbacks,
                                       dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")


yscore = CnnCrispr_model.predict(xtest5)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest5, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# cnn_crispr model
# GloVe model loaded
# load data!
# encoded_CnnCrispr_SITE.pkl
# 136937
# xtrain shape: (139348, 23)
# 139348 train samples
# 43547 test samples
# 34838 val samples
# 2411
# 136937
# 2140.0
# Training!!
# Initial GPU Memory Usage: 7234.0 MB
# Epoch 1/30
# 2140/2140 [==============================] - 32s 15ms/step - loss: 0.7071 - accuracy: 0.4996 - f1_metric: 0.4996 - val_loss: 0.6972 - val_accuracy: 0.4422 - val_f1_metric: 0.4413
# Epoch 2/30
# 2140/2140 [==============================] - 31s 14ms/step - loss: 0.6934 - accuracy: 0.5006 - f1_metric: 0.5006 - val_loss: 0.7234 - val_accuracy: 0.1222 - val_f1_metric: 0.1220
# Epoch 3/30
# 2140/2140 [==============================] - 31s 15ms/step - loss: 0.6933 - accuracy: 0.5004 - f1_metric: 0.5004 - val_loss: 0.6571 - val_accuracy: 0.2033 - val_f1_metric: 0.2052
# Epoch 4/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.5003 - f1_metric: 0.5003 - val_loss: 45637681152.0000 - val_accuracy: 0.7902 - val_f1_metric: 0.7906
# Epoch 5/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.5002 - f1_metric: 0.5002 - val_loss: 0.6709 - val_accuracy: 0.9493 - val_f1_metric: 0.9494
# Epoch 6/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.4996 - f1_metric: 0.4996 - val_loss: 0.9217 - val_accuracy: 0.8450 - val_f1_metric: 0.8449
# Epoch 7/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.4994 - f1_metric: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.0689 - val_f1_metric: 0.0692
# Epoch 8/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.4999 - f1_metric: 0.4999 - val_loss: 0.7068 - val_accuracy: 0.0330 - val_f1_metric: 0.0329
# Epoch 9/30
# 2140/2140 [==============================] - 29s 13ms/step - loss: 0.6932 - accuracy: 0.4984 - f1_metric: 0.4984 - val_loss: 0.6817 - val_accuracy: 0.9795 - val_f1_metric: 0.9795
# Epoch 10/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.5003 - f1_metric: 0.5003 - val_loss: 0.6885 - val_accuracy: 0.9827 - val_f1_metric: 0.9827
# Epoch 11/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.4997 - f1_metric: 0.4997 - val_loss: 0.7394 - val_accuracy: 0.0357 - val_f1_metric: 0.0356
# Epoch 12/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.4990 - f1_metric: 0.4990 - val_loss: 0.6969 - val_accuracy: 0.0286 - val_f1_metric: 0.0286
# Epoch 13/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.5003 - f1_metric: 0.5003 - val_loss: 0.6948 - val_accuracy: 0.9684 - val_f1_metric: 0.9685
# Epoch 14/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.4998 - f1_metric: 0.4998 - val_loss: 0.6994 - val_accuracy: 0.0208 - val_f1_metric: 0.0208
# Epoch 15/30
# 2140/2140 [==============================] - 29s 13ms/step - loss: 0.6932 - accuracy: 0.5022 - f1_metric: 0.5022 - val_loss: 0.7887 - val_accuracy: 0.9149 - val_f1_metric: 0.9146
# Epoch 16/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.4990 - f1_metric: 0.4990 - val_loss: 0.7057 - val_accuracy: 0.0305 - val_f1_metric: 0.0304
# Epoch 17/30
# 2140/2140 [==============================] - 31s 15ms/step - loss: 0.6932 - accuracy: 0.4993 - f1_metric: 0.4993 - val_loss: 0.7208 - val_accuracy: 0.0264 - val_f1_metric: 0.0263
# Epoch 18/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.4983 - f1_metric: 0.4983 - val_loss: 0.6891 - val_accuracy: 0.9826 - val_f1_metric: 0.9824
# Epoch 19/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.5006 - f1_metric: 0.5006 - val_loss: 0.6941 - val_accuracy: 0.0197 - val_f1_metric: 0.0197
# Epoch 20/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.5000 - f1_metric: 0.5000 - val_loss: 0.6972 - val_accuracy: 0.0305 - val_f1_metric: 0.0304
# Training Time: 598.75 seconds
# Final GPU Memory Usage: 7234.0 MB
# Accuracy                0.0186
# F1 score                 0.034
# Precision               0.0173
# Recall                  0.9987
# ROC AUC                 0.5003
# PR AUC                  0.0173
