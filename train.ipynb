# %%
import tensorflow as tf
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_auc_score, average_precision_score
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import model_get
import pickle as pkl
import time
import GPUtil

# %% [markdown]
# # Utils

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)

def loadGlove(inputpath, outputpath=""):
    data_list = []
    wordEmb = {}
    with open(inputpath) as f:
        for line in f:
            ll = line.strip().split(',')
            ll[0] = str(int(float(ll[0])))
            data_list.append(ll)

            ll_new = [float(i) for i in ll]
            emb = np.array(ll_new[1:], dtype="float32")
            wordEmb[str(int(ll_new[0]))] = emb

    if outputpath != "":
        with open(outputpath) as f:
            for data in data_list:
                f.writelines(' '.join(data))
    return wordEmb

# %% [markdown]
# # Setting

# %%
import random
import os
seed = 123
random.seed(seed)
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)


def f1_metric(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
    predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    f1_val = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
    return f1_val


early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_f1_metric', min_delta=0.0001,
    patience=10, verbose=0, mode='max')
callbacks = [early_stopping]

dataset = 'k562'

num_classes = 2
epochs = 30
batch_size = 128
flpath = 'data/'


retrain = False

# %% [markdown]
# # Model Training

# %% [markdown]
# CrisprIP

# %%
print('crispr_ip_model')
encoder_shape = (23, 6)
seg_len, coding_dim = encoder_shape

open_name = 'encoded6x23' + dataset + '.pkl'


print('load data!')
print(open_name)

loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    np.array(loaddata.images),
    loaddata.target,  # loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,  # loaddata.target,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)



xtrain, xtest1, ytrain, ytest1, xval, yval, inputshape = model_get.transformIO(
    x_train, x_test, y_train, y_test, x_val, y_val, seg_len, coding_dim, num_classes)

pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))

pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()

resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)
resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)


print('Training!!')
# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")

crispr_ip_model = model_get.crispr_ip(test_ds, resampled_steps_per_epoch, resampled_ds, xtrain, ytrain,
                                       xtest1,
                                       ytest1,
                                       inputshape, num_classes, batch_size, epochs, callbacks,
                                       dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")


yscore = crispr_ip_model.predict(xtest1)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest1, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# crispr_ip_model
# load data!
# encoded6x23ELEVATION.pkl
# 136884
# xtrain shape: (136916, 1, 23, 6)
# 136916 train samples
# 42787 test samples
# 34230 val samples
# 32
# 136884
# 2139.0
# Training!!
# Initial GPU Memory Usage: 6838.0 MB
# Epoch 1/30
# 2139/2139 [==============================] - 21s 10ms/step - loss: 0.6964 - accuracy: 0.4998 - f1_metric: 0.4998 - val_loss: 0.7098 - val_accuracy: 0.0025 - val_f1_metric: 0.0025
# Epoch 2/30
# 2139/2139 [==============================] - 20s 10ms/step - loss: 0.6935 - accuracy: 0.5005 - f1_metric: 0.5005 - val_loss: 0.7123 - val_accuracy: 2.3371e-04 - val_f1_metric: 2.3321e-04
# Epoch 3/30
# 2139/2139 [==============================] - 20s 10ms/step - loss: 0.6932 - accuracy: 0.5004 - f1_metric: 0.5004 - val_loss: 0.6944 - val_accuracy: 0.0028 - val_f1_metric: 0.0028
# Epoch 4/30
# 2139/2139 [==============================] - 21s 10ms/step - loss: 0.6932 - accuracy: 0.4999 - f1_metric: 0.4999 - val_loss: 0.6787 - val_accuracy: 0.9997 - val_f1_metric: 0.9997
# Epoch 5/30
# 2139/2139 [==============================] - 21s 10ms/step - loss: 0.6932 - accuracy: 0.4998 - f1_metric: 0.4998 - val_loss: 0.6930 - val_accuracy: 0.9975 - val_f1_metric: 0.9975
# Epoch 6/30
# 2139/2139 [==============================] - 21s 10ms/step - loss: 0.6932 - accuracy: 0.4994 - f1_metric: 0.4994 - val_loss: 0.6920 - val_accuracy: 0.9972 - val_f1_metric: 0.9972
# Epoch 7/30
# 2139/2139 [==============================] - 21s 10ms/step - loss: 0.6932 - accuracy: 0.4994 - f1_metric: 0.4994 - val_loss: 0.6992 - val_accuracy: 2.3371e-04 - val_f1_metric: 2.3321e-04
# Epoch 8/30
# 2139/2139 [==============================] - 21s 10ms/step - loss: 0.6933 - accuracy: 0.5000 - f1_metric: 0.5000 - val_loss: 0.7309 - val_accuracy: 2.3371e-04 - val_f1_metric: 2.3321e-04
# Epoch 9/30
# 2139/2139 [==============================] - 24s 11ms/step - loss: 0.6932 - accuracy: 0.4984 - f1_metric: 0.4984 - val_loss: 0.6944 - val_accuracy: 0.0024 - val_f1_metric: 0.0024
# Epoch 10/30
# 2139/2139 [==============================] - 24s 11ms/step - loss: 0.6932 - accuracy: 0.5003 - f1_metric: 0.5003 - val_loss: 0.6859 - val_accuracy: 0.9949 - val_f1_metric: 0.9949
# Epoch 11/30
# 2139/2139 [==============================] - 23s 11ms/step - loss: 0.6932 - accuracy: 0.4997 - f1_metric: 0.4997 - val_loss: 0.6923 - val_accuracy: 0.9946 - val_f1_metric: 0.9945
# Epoch 12/30
# 2139/2139 [==============================] - 22s 10ms/step - loss: 0.6932 - accuracy: 0.4989 - f1_metric: 0.4989 - val_loss: 0.7222 - val_accuracy: 0.0072 - val_f1_metric: 0.0073
# Epoch 13/30
# 2139/2139 [==============================] - 21s 10ms/step - loss: 0.6932 - accuracy: 0.5003 - f1_metric: 0.5003 - val_loss: 0.6886 - val_accuracy: 0.9998 - val_f1_metric: 0.9998
# Epoch 14/30
# 2139/2139 [==============================] - 21s 10ms/step - loss: 0.6932 - accuracy: 0.4995 - f1_metric: 0.4995 - val_loss: 0.6982 - val_accuracy: 0.0033 - val_f1_metric: 0.0033
# Training Time: 302.38 seconds
# Final GPU Memory Usage: 6838.0 MB
# Accuracy                0.0061
# F1 score                0.0005
# Precision               0.0002
# Recall                     1.0
# ROC AUC                 0.4978
# PR AUC                  0.0002

# %% [markdown]
# cnn_std

# %%
print('cnn_std')
encoder_shape = (23, 4)
seg_len, coding_dim = encoder_shape
open_name = 'encoded4x23' + dataset + '.pkl'

print('load data!')
print(open_name)

loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    np.array(loaddata.images),
    loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)

xtrain, xtest2, ytrain, ytest2, xval, yval, input_shape = model_get.cnn_std_transformIO(x_train, x_test,
                                                                                         y_train,
                                                                                         y_test, x_val, y_val,
                                                                                         seg_len, coding_dim,
                                                                                         num_classes)
pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))

pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()

resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)
resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)

print('Training!!')
# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")
cnn_std_model = model_get.cnn_std(test_ds, resampled_steps_per_epoch, resampled_ds, xtrain, ytrain,
                                   xtest2,
                                   ytest2, num_classes, batch_size, epochs, callbacks,
                                   dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")

yscore = cnn_std_model.predict(xtest2)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest2, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# cnn_std
# load data!
# encoded4x23k562.pkl
# 11722
# xtrain shape: (11797, 1, 23, 4)
# 11797 train samples
# 3687 test samples
# 2950 xval samples
# 75
# 11722
# 184.0
# Training!!
# Initial GPU Memory Usage: 2144.0 MB
# Epoch 1/30
# 184/184 [==============================] - 1s 5ms/step - loss: 0.6932 - accuracy: 0.4976 - f1_metric: 0.4949 - val_loss: 0.6930 - val_accuracy: 0.9936 - val_f1_metric: 0.9938
# Epoch 2/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.4982 - f1_metric: 0.4982 - val_loss: 0.6918 - val_accuracy: 0.9936 - val_f1_metric: 0.9938
# Epoch 3/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.4972 - f1_metric: 0.4972 - val_loss: 0.6932 - val_accuracy: 0.0064 - val_f1_metric: 0.0062
# Epoch 4/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.5032 - f1_metric: 0.5032 - val_loss: 0.6886 - val_accuracy: 0.9936 - val_f1_metric: 0.9938
# Epoch 5/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.5006 - f1_metric: 0.5006 - val_loss: 0.6957 - val_accuracy: 0.0064 - val_f1_metric: 0.0062
# Epoch 6/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6931 - accuracy: 0.5028 - f1_metric: 0.5028 - val_loss: 0.7022 - val_accuracy: 0.0064 - val_f1_metric: 0.0062
# Epoch 7/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.4958 - f1_metric: 0.4958 - val_loss: 0.6951 - val_accuracy: 0.0064 - val_f1_metric: 0.0062
# Epoch 8/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.4987 - f1_metric: 0.4987 - val_loss: 0.6906 - val_accuracy: 0.9936 - val_f1_metric: 0.9938
# Epoch 9/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.5019 - f1_metric: 0.5019 - val_loss: 0.6948 - val_accuracy: 0.0064 - val_f1_metric: 0.0062
# Epoch 10/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.4982 - f1_metric: 0.4982 - val_loss: 0.6890 - val_accuracy: 0.9936 - val_f1_metric: 0.9938
# Epoch 11/30
# 184/184 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.4989 - f1_metric: 0.4989 - val_loss: 0.7047 - val_accuracy: 0.0064 - val_f1_metric: 0.0062
# Training Time: 8.36 seconds
# Final GPU Memory Usage: 2144.0 MB
# Accuracy                0.0065
# F1 score                0.0129
# Precision               0.0065
# Recall                     1.0
# ROC AUC                    0.5
# PR AUC                  0.0065

# %% [markdown]
# crisprDNT

# %%
print('crisprDNT')
open_name = 'encodedmismatchtype14x23' + dataset + '.pkl'
encoder_shape = (23, 14)
seg_len, coding_dim = encoder_shape

print('load data!')
print(open_name)

loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    loaddata.images,
    loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)

xtrain, xtest3, ytrain, ytest3, xval, yval, inputshape = model_get.transformIO(
    x_train, x_test, y_train, y_test, x_val, y_val, seg_len, coding_dim, num_classes)

pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))
pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()

resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)
resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)

print('Training!!')
# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")

crisprDNT = model_get.crisprDNT(test_ds, resampled_steps_per_epoch, resampled_ds, xtrain, ytrain,
                                     xtest3,
                                     ytest3,
                                     inputshape, num_classes, batch_size, epochs, callbacks,
                                     dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")


yscore = crisprDNT.predict(xtest3)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest3, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# crisprDNT
# load data!
# encodedmismatchtype14x23ELEVATION.pkl
# 136884
# xtrain shape: (136916, 1, 23, 14)
# 136916 train samples
# 42787 test samples
# 34230 val samples
# 32
# 136884
# 2139.0
# Training!!
# Initial GPU Memory Usage: 7964.0 MB
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/30
# 2139/2139 [==============================] - 546s 255ms/step - loss: 0.0618 - accuracy: 0.9732 - f1_metric: 0.9732 - val_loss: 0.1244 - val_accuracy: 0.9467 - val_f1_metric: 0.9467
# Epoch 2/30
# 2139/2139 [==============================] - 538s 252ms/step - loss: 0.0036 - accuracy: 0.9991 - f1_metric: 0.9991 - val_loss: 0.0090 - val_accuracy: 0.9972 - val_f1_metric: 0.9972
# Epoch 3/30
# 2139/2139 [==============================] - 531s 248ms/step - loss: 0.0023 - accuracy: 0.9995 - f1_metric: 0.9995 - val_loss: 0.0060 - val_accuracy: 0.9991 - val_f1_metric: 0.9991
# Epoch 4/30
# 2139/2139 [==============================] - 527s 246ms/step - loss: 0.0020 - accuracy: 0.9996 - f1_metric: 0.9996 - val_loss: 0.0060 - val_accuracy: 0.9994 - val_f1_metric: 0.9994
# Epoch 5/30
# 2139/2139 [==============================] - 512s 239ms/step - loss: 0.0014 - accuracy: 0.9997 - f1_metric: 0.9997 - val_loss: 0.0068 - val_accuracy: 0.9996 - val_f1_metric: 0.9996
# Epoch 6/30
# 2139/2139 [==============================] - 520s 243ms/step - loss: 0.0012 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0069 - val_accuracy: 0.9996 - val_f1_metric: 0.9996
# Epoch 7/30
# 2139/2139 [==============================] - 508s 238ms/step - loss: 0.0011 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0087 - val_accuracy: 0.9989 - val_f1_metric: 0.9989
# Epoch 8/30
# 2139/2139 [==============================] - 511s 239ms/step - loss: 0.0012 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0349 - val_accuracy: 0.9945 - val_f1_metric: 0.9945
# Epoch 9/30
# 2139/2139 [==============================] - 246s 115ms/step - loss: 9.8997e-04 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0077 - val_accuracy: 0.9995 - val_f1_metric: 0.9995
# Epoch 10/30
# 2139/2139 [==============================] - 248s 116ms/step - loss: 8.1363e-04 - accuracy: 0.9999 - f1_metric: 0.9999 - val_loss: 0.0072 - val_accuracy: 0.9995 - val_f1_metric: 0.9995
# Epoch 11/30
# 2139/2139 [==============================] - 249s 116ms/step - loss: 8.3111e-04 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0066 - val_accuracy: 0.9993 - val_f1_metric: 0.9993
# Epoch 12/30
# 2139/2139 [==============================] - 247s 116ms/step - loss: 8.1569e-04 - accuracy: 0.9999 - f1_metric: 0.9999 - val_loss: 0.0066 - val_accuracy: 0.9992 - val_f1_metric: 0.9992
# Epoch 13/30
# 2139/2139 [==============================] - 248s 116ms/step - loss: 0.0011 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0068 - val_accuracy: 0.9995 - val_f1_metric: 0.9995
# Epoch 14/30
# 2139/2139 [==============================] - 249s 116ms/step - loss: 7.4135e-04 - accuracy: 0.9999 - f1_metric: 0.9999 - val_loss: 0.0066 - val_accuracy: 0.9995 - val_f1_metric: 0.9995
# Epoch 15/30
# 2139/2139 [==============================] - 249s 116ms/step - loss: 7.8198e-04 - accuracy: 0.9999 - f1_metric: 0.9999 - val_loss: 0.0065 - val_accuracy: 0.9993 - val_f1_metric: 0.9993
# Training Time: 5936.86 seconds
# Final GPU Memory Usage: 7964.0 MB
# Accuracy                0.9993
# F1 score                0.1667
# Precision               0.1154
# Recall                     0.3
# ROC AUC                 0.9944
# PR AUC                  0.0877

# %% [markdown]
# crisprNet

# %%
print('CRISPR_Net')
open_name = 'encoded7x23' + dataset + '.pkl'
encoder_shape = (23, 7)
seg_len, coding_dim = encoder_shape
print('load data!')
print(open_name)
loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    loaddata.images,
    loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)

xtrain, xtest4, ytrain, ytest4, xval, yval, inputshape = model_get.CRISPR_Net_transformIO(
    x_train, x_test, y_train, y_test, x_val, y_val, seg_len, coding_dim, num_classes)

pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))

pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()
resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)

resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)

print('Training!!')
# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")

CRISPR_Net_model = model_get.CRISPR_Net_model(test_ds, resampled_steps_per_epoch, resampled_ds,
                                               xtrain, ytrain,
                                               xtest4,
                                               ytest4,
                                               inputshape, num_classes, batch_size, epochs, callbacks,
                                               dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")


yscore = CRISPR_Net_model.predict(xtest4)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest4, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# CRISPR_Net
# load data!
# encoded7x23ELEVATION.pkl
# 136884
# xtrain shape: (136916, 1, 23, 7)
# 136916 train samples
# 42787 test samples
# 34230 val samples
# 32
# 136884
# 2139.0
# Training!!
# Initial GPU Memory Usage: 6838.0 MB
# Epoch 1/30
# 2139/2139 [==============================] - 20s 9ms/step - loss: 0.0535 - accuracy: 0.9802 - f1_metric: 0.9802 - val_loss: 0.0141 - val_accuracy: 0.9954 - val_f1_metric: 0.9952
# Epoch 2/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0094 - accuracy: 0.9970 - f1_metric: 0.9970 - val_loss: 0.0058 - val_accuracy: 0.9985 - val_f1_metric: 0.9985
# Epoch 3/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0073 - accuracy: 0.9974 - f1_metric: 0.9974 - val_loss: 0.0034 - val_accuracy: 0.9993 - val_f1_metric: 0.9993
# Epoch 4/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0036 - accuracy: 0.9989 - f1_metric: 0.9989 - val_loss: 0.0053 - val_accuracy: 0.9993 - val_f1_metric: 0.9991
# Epoch 5/30
# 2139/2139 [==============================] - 18s 9ms/step - loss: 0.0019 - accuracy: 0.9994 - f1_metric: 0.9994 - val_loss: 0.0545 - val_accuracy: 0.9557 - val_f1_metric: 0.9555
# Epoch 6/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0023 - accuracy: 0.9993 - f1_metric: 0.9993 - val_loss: 0.0054 - val_accuracy: 0.9992 - val_f1_metric: 0.9988
# Epoch 7/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0031 - accuracy: 0.9990 - f1_metric: 0.9990 - val_loss: 0.0095 - val_accuracy: 0.9994 - val_f1_metric: 0.9989
# Epoch 8/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0022 - accuracy: 0.9994 - f1_metric: 0.9994 - val_loss: 0.0039 - val_accuracy: 0.9996 - val_f1_metric: 0.9996
# Epoch 9/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0016 - accuracy: 0.9996 - f1_metric: 0.9996 - val_loss: 0.0046 - val_accuracy: 0.9996 - val_f1_metric: 0.9996
# Epoch 10/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 4.5477e-04 - accuracy: 0.9999 - f1_metric: 0.9999 - val_loss: 0.0061 - val_accuracy: 0.9995 - val_f1_metric: 0.9992
# Epoch 11/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0012 - accuracy: 0.9997 - f1_metric: 0.9997 - val_loss: 0.0067 - val_accuracy: 0.9995 - val_f1_metric: 0.9995
# Epoch 12/30
# 2139/2139 [==============================] - 18s 8ms/step - loss: 0.0012 - accuracy: 0.9997 - f1_metric: 0.9997 - val_loss: 0.0062 - val_accuracy: 0.9997 - val_f1_metric: 0.9997
# Epoch 13/30
# 2139/2139 [==============================] - 18s 9ms/step - loss: 8.0798e-04 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0149 - val_accuracy: 0.9987 - val_f1_metric: 0.9983
# Epoch 14/30
# 2139/2139 [==============================] - 18s 9ms/step - loss: 5.1897e-04 - accuracy: 0.9999 - f1_metric: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9992 - val_f1_metric: 0.9987
# Epoch 15/30
# 2139/2139 [==============================] - 18s 9ms/step - loss: 9.8631e-04 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0102 - val_accuracy: 0.9993 - val_f1_metric: 0.9989
# Epoch 16/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 8.7600e-04 - accuracy: 0.9998 - f1_metric: 0.9998 - val_loss: 0.0091 - val_accuracy: 0.9993 - val_f1_metric: 0.9989
# Epoch 17/30
# 2139/2139 [==============================] - 18s 9ms/step - loss: 2.4644e-04 - accuracy: 0.9999 - f1_metric: 0.9999 - val_loss: 0.0122 - val_accuracy: 0.9992 - val_f1_metric: 0.9988
# Epoch 18/30
# 2139/2139 [==============================] - 19s 9ms/step - loss: 0.0012 - accuracy: 0.9997 - f1_metric: 0.9997 - val_loss: 0.0080 - val_accuracy: 0.9994 - val_f1_metric: 0.9989
# Training Time: 340.30 seconds
# Final GPU Memory Usage: 6838.0 MB
# Accuracy                0.9997
# F1 score                 0.381
# Precision               0.3636
# Recall                     0.4
# ROC AUC                 0.9924
# PR AUC                    0.25

# %% [markdown]
# cnnCRISPR

# %%
print('cnn_crispr model')
print("GloVe model loaded")
VOCAB_SIZE = 16  # 4**3
EMBED_SIZE = 100
glove_inputpath = "data/keras_GloVeVec_" + dataset + "_5_100_10000.csv"
# load GloVe model
model_glove = loadGlove(glove_inputpath)
embedding_weights = np.zeros((VOCAB_SIZE, EMBED_SIZE))
for i in range(VOCAB_SIZE):
    embedding_weights[i, :] = model_glove[str(i)]

open_name = 'encoded_CnnCrispr_' + dataset + '.pkl'


print('load data!')
print(open_name)

loaddata = pkl.load(
    open(flpath + open_name, 'rb'),
    encoding='latin1'
)

x_train, x_test, y_train, y_test = train_test_split(
    np.array(loaddata.images),
    loaddata.target,
    stratify=pd.Series(loaddata.target),
    test_size=0.2,
    shuffle=True,
    random_state=42)

x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    stratify=pd.Series(y_train),
    test_size=0.2,
    shuffle=True,
    random_state=42)

neg = 0
for i in y_train:
    if i == 0:
        neg += 1
print(neg)

xtrain, xtest5, ytrain, ytest5, xval, yval = model_get.offt_transformIO(x_train, x_test, y_train, y_test,
                                                                         x_val, y_val, num_classes)

pos_indices = y_train == 1
pos_x, neg_x = xtrain[pos_indices], xtrain[~pos_indices]
pos_y, neg_y = ytrain[pos_indices], ytrain[~pos_indices]
print(len(pos_y))
print(len(neg_y))

pos_ds = tf.data.Dataset.from_tensor_slices((pos_x, pos_y)).repeat()
neg_ds = tf.data.Dataset.from_tensor_slices((neg_x, neg_y)).repeat()

resampled_ds = tf.data.experimental.sample_from_datasets([pos_ds, neg_ds], weights=[0.5, 0.5], seed=seed)
resampled_ds = resampled_ds.batch(batch_size).prefetch(2)
resampled_steps_per_epoch = np.ceil(2 * neg / batch_size)
print(resampled_steps_per_epoch)

test_ds = tf.data.Dataset.from_tensor_slices((xval, yval)).cache()
test_ds = test_ds.batch(batch_size)

print('Training!!')

# Record the start time 
start_time = time.time()
# Fetch GPU details and record initial memory usage
GPUs = GPUtil.getGPUs()
gpu = GPUs[0]
initial_memory = gpu.memoryUsed
print(f"Initial GPU Memory Usage: {initial_memory} MB")

CnnCrispr_model = model_get.CnnCrispr(embedding_weights, test_ds, resampled_steps_per_epoch, resampled_ds,
                                       xtrain, ytrain,
                                       xtest5,
                                       ytest5, num_classes, batch_size, epochs, callbacks,
                                       dataset, retrain)

# Record the end time 
end_time = time.time()
# Calculate the time 
time_taken = end_time - start_time
print(f"Training Time: {time_taken:.2f} seconds")
# After training, record the final memory usage and calculate the difference
final_memory = gpu.memoryUsed
print(f"Final GPU Memory Usage: {final_memory} MB")


yscore = CnnCrispr_model.predict(xtest5)
ypred = np.argmax(yscore, axis=1)
yscore = yscore[:, 1]
ytest = np.argmax(ytest5, axis=1)
eval_funs = [accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, average_precision_score]
eval_fun_names = ['Accuracy', 'F1 score', 'Precision', 'Recall', 'ROC AUC', 'PR AUC']
eval_fun_types = [True, True, True, True, False, False]
for index_f, function in enumerate(eval_funs):
    if eval_fun_types[index_f]:
        score = np.round(function(ytest, ypred), 4)
    else:
        score = np.round(function(ytest, yscore), 4)
    print('{:<15}{:>15}'.format(eval_fun_names[index_f], score))
# Out:
# cnn_crispr model
# GloVe model loaded
# load data!
# encoded_CnnCrispr_SITE.pkl
# 136937
# xtrain shape: (139348, 23)
# 139348 train samples
# 43547 test samples
# 34838 val samples
# 2411
# 136937
# 2140.0
# Training!!
# Initial GPU Memory Usage: 7234.0 MB
# Epoch 1/30
# 2140/2140 [==============================] - 32s 15ms/step - loss: 0.7071 - accuracy: 0.4996 - f1_metric: 0.4996 - val_loss: 0.6972 - val_accuracy: 0.4422 - val_f1_metric: 0.4413
# Epoch 2/30
# 2140/2140 [==============================] - 31s 14ms/step - loss: 0.6934 - accuracy: 0.5006 - f1_metric: 0.5006 - val_loss: 0.7234 - val_accuracy: 0.1222 - val_f1_metric: 0.1220
# Epoch 3/30
# 2140/2140 [==============================] - 31s 15ms/step - loss: 0.6933 - accuracy: 0.5004 - f1_metric: 0.5004 - val_loss: 0.6571 - val_accuracy: 0.2033 - val_f1_metric: 0.2052
# Epoch 4/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.5003 - f1_metric: 0.5003 - val_loss: 45637681152.0000 - val_accuracy: 0.7902 - val_f1_metric: 0.7906
# Epoch 5/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.5002 - f1_metric: 0.5002 - val_loss: 0.6709 - val_accuracy: 0.9493 - val_f1_metric: 0.9494
# Epoch 6/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.4996 - f1_metric: 0.4996 - val_loss: 0.9217 - val_accuracy: 0.8450 - val_f1_metric: 0.8449
# Epoch 7/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.4994 - f1_metric: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.0689 - val_f1_metric: 0.0692
# Epoch 8/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.4999 - f1_metric: 0.4999 - val_loss: 0.7068 - val_accuracy: 0.0330 - val_f1_metric: 0.0329
# Epoch 9/30
# 2140/2140 [==============================] - 29s 13ms/step - loss: 0.6932 - accuracy: 0.4984 - f1_metric: 0.4984 - val_loss: 0.6817 - val_accuracy: 0.9795 - val_f1_metric: 0.9795
# Epoch 10/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.5003 - f1_metric: 0.5003 - val_loss: 0.6885 - val_accuracy: 0.9827 - val_f1_metric: 0.9827
# Epoch 11/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.4997 - f1_metric: 0.4997 - val_loss: 0.7394 - val_accuracy: 0.0357 - val_f1_metric: 0.0356
# Epoch 12/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.4990 - f1_metric: 0.4990 - val_loss: 0.6969 - val_accuracy: 0.0286 - val_f1_metric: 0.0286
# Epoch 13/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.5003 - f1_metric: 0.5003 - val_loss: 0.6948 - val_accuracy: 0.9684 - val_f1_metric: 0.9685
# Epoch 14/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.4998 - f1_metric: 0.4998 - val_loss: 0.6994 - val_accuracy: 0.0208 - val_f1_metric: 0.0208
# Epoch 15/30
# 2140/2140 [==============================] - 29s 13ms/step - loss: 0.6932 - accuracy: 0.5022 - f1_metric: 0.5022 - val_loss: 0.7887 - val_accuracy: 0.9149 - val_f1_metric: 0.9146
# Epoch 16/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.4990 - f1_metric: 0.4990 - val_loss: 0.7057 - val_accuracy: 0.0305 - val_f1_metric: 0.0304
# Epoch 17/30
# 2140/2140 [==============================] - 31s 15ms/step - loss: 0.6932 - accuracy: 0.4993 - f1_metric: 0.4993 - val_loss: 0.7208 - val_accuracy: 0.0264 - val_f1_metric: 0.0263
# Epoch 18/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.4983 - f1_metric: 0.4983 - val_loss: 0.6891 - val_accuracy: 0.9826 - val_f1_metric: 0.9824
# Epoch 19/30
# 2140/2140 [==============================] - 30s 14ms/step - loss: 0.6932 - accuracy: 0.5006 - f1_metric: 0.5006 - val_loss: 0.6941 - val_accuracy: 0.0197 - val_f1_metric: 0.0197
# Epoch 20/30
# 2140/2140 [==============================] - 29s 14ms/step - loss: 0.6932 - accuracy: 0.5000 - f1_metric: 0.5000 - val_loss: 0.6972 - val_accuracy: 0.0305 - val_f1_metric: 0.0304
# Training Time: 598.75 seconds
# Final GPU Memory Usage: 7234.0 MB
# Accuracy                0.0186
# F1 score                 0.034
# Precision               0.0173
# Recall                  0.9987
# ROC AUC                 0.5003
# PR AUC                  0.0173
